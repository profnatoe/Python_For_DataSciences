# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
insurance_data = pd.read_csv("insurance.csv")
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Determine our x and y values
# plot the data in a scatter plot 

x = insurance_data.age.values
y = insurance_data.charges.values

plt.scatter(x,y,color = 'r')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
#fitting a linear regression model
charges_model = LinearRegression()
charges_model.fit(x,y)
# Out:
# LinearRegression()

# %%
#predit the data and plot a scatter plot with best fit

y_pred = charges_model.predict(x)

plt.scatter(x,y,color = 'b')
plt.plot(x,y_pred,color = 'r')
plt.ylabel('Charges')
plt.xlabel('Age')
plt.show()

# %%
###Doing the same thing for bmi and insurance costs

# %%
xbmi = insurance_data[['bmi']].values
ycharges = insurance_data[['charges']].values

#plot: scatter plot
plt.scatter(xbmi,ycharges,color = 'b')
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.show()

# %%
#fitting a linear regression model
#insurance_data.reshape(1, -1)
model = LinearRegression()
model.fit(xbmi,y_charges)
# Out:
# LinearRegression()

# %%
#predit the data and plot a scatter plot with best fit

y_pred = model.predict(xbmi)

plt.scatter(xbmi,ycharges,color = 'b')
plt.plot(xbmi,y_pred,color = 'r')
plt.ylabel('Charges')
plt.xlabel('BMI')
plt.show()
