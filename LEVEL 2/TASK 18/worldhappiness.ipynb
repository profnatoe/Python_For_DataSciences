# %% [markdown]
# # THE WORLD HAPPINESS REPORT EDA: EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# WE IN THIS WORLD WE OFTEN SAY THAT PEOPLE ARE AT PEACE WHEN THEY ARE HAPPY. THIS IS BECAUSE WHEN PEOPLE ARE  ALL HAPPY THE MIND IS ABLE TO DO THINGS AT MAXIMUM POTENTIAL. HOWEVER WHEN HAPPINESS IN PEOPLE IS NOT THERE IT AFFECTS HOW THEY LIVE, HOW THEY INTERACT WITH OTHERS IN THEIR COMMUNITY, PSYCHOLOGICALLY AND PHYSICALLY. IN THIS PROJECT WE ARE GOING TO LOOK AT DATA ABOUT WORLD HAPPINESS REPORT CONDUCTED IN 2015 AND 2019.
#
#
# THIS SURVEY LOOKES AT NATIONAL HAPPINESS LEVELS ACCROSS COUNTRIES AS A MEASURE OF NATIONAL PROGRRESS. THE DATA USED IS FROM THE GALLUP WORLD POLL. THE ANSWERS ARE BASED ON ANSWERS TO THE MAIN LIFE EVALUATION ASKED IN THE POLL. THE COLUMNS FOLLOWING THE HAPPINESS SCORE ESTIMATE THE EXTENT TO WHICH EACH OF THE 6 FACTORS BELOW CONTRIBUTE TO MAKING LIFE EVALUATIONS HIGHER IN EACH COUNRTY THAN THEY ARE IN DYSTOPIA, A HYPOTHETICAL COUNTRY THAT HAS VALUES EQUAL TO THE WORLD'S LOWEST NATIONAL AVERAGES FOR EACH OF THE SIX FACTORS. THEY HAVE NO IMPACT ON THE TOTAL SCORE REPORTED FOR EACH COUNTRY, BUT THEY DO EXPLAIN WHY SOME COUNTRIES RANK HIGHER THAN OTHERS.
#
# #### THE SIX CHARACTERISTICS
#
#
# 1) GDP PER CAPITA
#
# 2) FAMILY QUALITY OF CITIZENS
#
# 3) HEALTH OF CITIZENS
#
# 4) FREEDOM OF CITIZENS
#
# 5) GENEROSITY OF CITIZENS
#
# 6) TRUST IN GOVERNMENT OF CITIZENS

# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preparation
#
# we will load the 2015 and 2019 data and view the first 5 rows for each report.
#
# furthermore we will create a short report of the dataframe which looks at the index, summary, shape, number of nulls, rows and columns and then display it so that we can use this later on for data cleaning

# %%
worldhappiness2015 = pd.read_csv('2015.csv')

# %%
worldhappiness2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#Details of the dataframe

#Check for missing values per column
isnull =  worldhappiness2015.isnull().sum()

#Dataframe shape
shape = worldhappiness2015.shape

#Check index
index = worldhappiness2015.index

#Check for duplicates
duplicates = worldhappiness2015.duplicated().sum()

#dataframe descriptive statistics
summary = worldhappiness2015.describe()

#number of rows and columns
rows = len(worldhappiness2015)
columns = worldhappiness2015.columns

#data types
dt = worldhappiness2015.dtypes


print("+---------------------------+")
print("|    Dataframe Summary      |")
print("+---------------------------+")
print("\n")
print("Data Types: \n\n", dt)
print("\n===============\nIndex: \n\n", index)
print("\n===============\nMissing Values: \n\n", isnull)
print("\n===============\nDuplicates: \n\n", duplicates)
print("\n===============\nRows: \n\n", rows)
print("\n===============\nColumns: \n\n", columns)
print("\n===============\nDataframe Shape: \n\n", shape)
print("\n===============\nSummary: \n\n", summary)
print("+-------------------------------------------+")
print("|   End Of World happiness 2015 Summary     |")
print("+-------------------------------------------+")
# Out:
# +---------------------------+
# |    Dataframe Summary      |
# +---------------------------+
#
#
# Data Types:
#
#  Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object
#
# ...
# Index:
#
#  RangeIndex(start=0, stop=158, step=1)
#
# ...
# Missing Values:
#
#  Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# ...

# %%
worldhappiness2019 = pd.read_csv('2019.csv')

# %%
worldhappiness2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#Details of the dataframe

#Check for missing values per column
isnull =  worldhappiness2019.isnull().sum()

#Dataframe shape
shape = worldhappiness2019.shape

#Check index
index = worldhappiness2019.index

#Check for duplicates
duplicates = worldhappiness2019.duplicated().sum()

#dataframe descriptive statistics
summary = worldhappiness2019.describe()

#number of rows and columns
rows = len(worldhappiness2019)
columns = worldhappiness2019.columns

#data types
dt = worldhappiness2019.dtypes


print("+---------------------------+")
print("|    Dataframe Summary      |")
print("+---------------------------+")
print("\n")
print("Data Types: \n\n", dt)
print("\n===============\nIndex: \n\n", index)
print("\n===============\nMissing Values: \n\n", isnull)
print("\n===============\nDuplicates: \n\n", duplicates)
print("\n===============\nRows: \n\n", rows)
print("\n===============\nColumns: \n\n", columns)
print("\n===============\nDataframe Shape: \n\n", shape)
print("\n===============\nSummary: \n\n", summary)
print("+-------------------------------------------+")
print("|   End Of World Happiness 2019 Summary     |")
print("+-------------------------------------------+")
# Out:
# +---------------------------+
# |    Dataframe Summary      |
# +---------------------------+
#
#
# Data Types:
#
#  Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object
#
# ...
# Index:
#
#  RangeIndex(start=0, stop=156, step=1)
#
# ...
# Missing Values:
#
#  Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64
#
# ...
# Duplicates:
#
#  0
#
# ...
# Rows:
#
#  156
#
# ...
# Columns:
#
# ...

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# it is evident that in 2015 we have a column called Dystopia Residual, Standard error and region which are not there in 2019.
#
# because of this uncommon of variables we are going to drop them for uniform dataframes.

# %%
# Dropping columns that are not common to all years

worldhappiness2015.drop(columns=['Standard Error', 'Region', 'Dystopia Residual'], inplace=True)

# %%
worldhappiness2015.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity
# 0     0.29678
# 1     0.43630
# ...

# %%
#Add a column with the year of the data collection

worldhappiness2015['Year'] = 2015
worldhappiness2019['Year'] = 2019
df_2019 = worldhappiness2019

# %%
#Reorder the columns to have a uniform order for both years
df_2015 = worldhappiness2015[['Happiness Rank', 'Country', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom','Generosity', 'Trust (Government Corruption)', 'Year']]

# %%
#Rename the columns
# 
df_2015.columns = ['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Year']

# %%
df_2019 = worldhappiness2019

#check column names
print(df_2015.columns)
print(df_2019.columns)
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
#merge the data

df_both = pd.concat([df_2015, df_2019])

df_both.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1       Switzerland  7.587         1.39651         1.34951
# 1             2           Iceland  7.561         1.30232         1.40223
# 2             3           Denmark  7.527         1.32548         1.36058
# 3             4            Norway  7.522         1.45900         1.33095
# 4             5            Canada  7.427         1.32629         1.32261
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                  0.94143                       0.66557     0.29678
# 1                  0.94784                       0.62877     0.43630
# 2                  0.87464                       0.64938     0.34139
# 3                  0.88521                       0.66973     0.34699
# 4                  0.90563                       0.63297     0.45811
#
#    Perceptions of corruption  Year
# 0                    0.41978  2015
# 1                    0.14145  2015
# ...

# %%
#check the tail of the data

df_both.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption  Year
# 151       0.217                      0.411  2019
# ...

# %% [markdown]
# ## Now we are sure that the data was merged successfully. we can move on to other things.
#
# ##### Let us try to understand our data

# %%
##view the shape

df_both.shape
# Out:
# (314, 10)

# %%
df_both.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 314 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  314 non-null    int64
#  1   Country or region             314 non-null    object
#  2   Score                         314 non-null    float64
#  3   GDP per capita                314 non-null    float64
#  4   Social support                314 non-null    float64
#  5   Healthy life expectancy       314 non-null    float64
#  6   Freedom to make life choices  314 non-null    float64
#  7   Generosity                    314 non-null    float64
#  8   Perceptions of corruption     314 non-null    float64
#  9   Year                          314 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 27.0+ KB

# %% [markdown]
# #### we can see that all the data here are numeric except for the country or region which is a string.
#
#
# ## Let us look at the NULL COLUMNS

# %%
df_both.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# Year                            0
# dtype: int64

# %% [markdown]
# ## there are no null columns, lets check for duplicates

# %%
df_both.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### There are no duplicated records.
#
#
# ## Let us look at the outliers in our data

# %%
#we will use boxplot

n_cols = df_both.select_dtypes('number').columns

for col in n_cols:
    plt.figure(figsize = (10, 8))
    df_both.boxplot([col])

# %% [markdown]
# ## as we can see that some columns have outliers we need to scale this for modelling

# %%
##Lets save the data to file first

df_both.to_csv('happiness_2015_2019.csv')

# %%
df_both.describe() #statistical description
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    314.000000  314.000000      314.000000      314.000000
# mean      79.000000    5.391315        0.875454        1.099236
# std       45.398695    1.127584        0.401226        0.305668
# min        1.000000    2.839000        0.000000        0.000000
# 25%       40.000000    4.537500        0.575000        0.916030
# 50%       79.000000    5.305000        0.946000        1.146000
# 75%      118.000000    6.189500        1.204750        1.313592
# max      158.000000    7.769000        1.690420        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               314.000000                    314.000000  314.000000
# mean                  0.677449                      0.410708    0.211238
# std                   0.248827                      0.147932    0.115036
# min                   0.000000                      0.000000    0.000000
# ...

# %% [markdown]
# ### Numerical variables Distribution

# %%
# Plotting distribution of numerical variables
fig, ax = plt.subplots(len(n_cols), figsize=(10,40))

for i, col_val in enumerate(n_cols):

    sns.distplot(df_both[col_val], hist=True, ax=ax[i])
    ax[i].set_title('Frequency distribution of '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)
    
plt.tight_layout()
plt.show()

# %%
# Checking kurtosis and skewness of numerical variables
for i, col_val in enumerate(n_cols):

    print(col_val)
    print("Skewness:", df_both[col_val].skew())
    print("Kurtosis:", df_both[col_val].kurt())
# Out:
# Overall rank
# Skewness: 0.000634011260779148
# Kurtosis: -1.1994412280310345
# Score
# Skewness: 0.055257161701631974
# Kurtosis: -0.7060155700374002
# GDP per capita
# Skewness: -0.34868928659705933
# Kurtosis: -0.8247702776259036
# Social support
# Skewness: -0.7901083443921587
# Kurtosis: 0.5596082753782539
# Healthy life expectancy
# Skewness: -0.6336134153840566
# Kurtosis: -0.29049564335561495
# Freedom to make life choices
# Skewness: -0.5061678179715507
# Kurtosis: -0.2393372048358624
# Generosity
# Skewness: 1.056050931722704
# Kurtosis: 2.1365166745639765
# Perceptions of corruption
# Skewness: 1.5480231080144067
# Kurtosis: 2.0253295673763834
# Year
# Skewness: 0.012800341366331807
# Kurtosis: -2.012696837261369

# %% [markdown]
# ### Observations a)  Skewness
#
#     1. Most of the data distributions are slightly skewed, with the exception of generosity and perceptions of corruption which are positively skewed.
#
# b) Kurtosis
#
#     1. The distributions for all the variables are platkurtic as they have low kurtosis. This is especially apparent for overall rank, GPD per capita and year.

# %%
# Plotting all features against happiness score
g = sns.PairGrid(df_both, y_vars=['Score'], x_vars=['GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption'], height=4)
g.map(sns.regplot)

# %% [markdown]
# ##### Here we see the Generosity and Perception of corruption having weakest correlation as compared to GPD per capita and Healthy life expectancy which are having the strongest correlation. it is also evident that all the features seem to have a linear relationship with happiness score

# %%
#Checking for correlations between the variables
plt.figure(dpi=100)
cor=df_both.corr(method = 'spearman')
sns.heatmap(cor, xticklabels=cor.columns, yticklabels=cor.columns, annot = True)
plt.xticks( rotation=90)
plt.title('Correlation between variables')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Looking at the above diagram we can see that Score here is highly correlated to  GPD per capita and Healthy life expectancy and weakly correlated to Generosity and perceptions of corruption

# %% [markdown]
# #####  We will start with our Modeling

# %%
#drop the unecessary columns
#use of standard scaler that scales thedata to a mean of 0 ad standard dev 1.
#useful for negative values,arrange data to normal distribution
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
df_mod = df_both.drop(columns = ['Overall rank', 'Country or region', 'Year'])

df_both = scaler.fit_transform(df_mod)

# %%
#dataframe that contains our features with column names
names = ['Score', 'GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']
df_both = pd.DataFrame(df_both, columns=names)

# %%
df_both #preview the new dataframe
# Out:
#         Score  GDP per capita  Social support  Healthy life expectancy  \
# 0    1.950356        1.300731        0.820083                 1.062595
# 1    1.927261        1.065601        0.992833                 1.088397
# 2    1.897060        1.123416        0.856356                 0.793747
# 3    1.892618        1.456727        0.759266                 0.836294
# 4    1.808233        1.125438        0.731938                 0.918490
# ..        ...             ...             ...                      ...
# 309 -1.827447       -1.289244       -1.272153                -0.255399
# 310 -1.918938       -0.997173       -0.701999                -0.718305
# 311 -1.943810       -1.311711       -1.907841                -1.273793
# 312 -2.050402       -2.120525       -3.601919                -2.304262
# 313 -2.254703       -1.421550       -1.717790                -1.539460
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# ...

# %%
#Spliting out data to independent and dependent features
#data split to training 80 and testing 20 
X = df_both[['GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

y = df_both['Score']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Visualizing the distribution of train data after scaling
cols = ['GDP per capita',
        'Healthy life expectancy',
       'Freedom to make life choices']

for col in cols:
  sns.distplot(X_train[col])

# %%
# Visualizing the distribution of test data after scaling
cols = ['GDP per capita',
        'Healthy life expectancy',
       'Freedom to make life choices']

for col in cols:
  sns.distplot(X_test[col])

# %% [markdown]
# The distributions are fairly similar now and closer to normal distribution.

# %%
# creating a decision tree regressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
tree = DecisionTreeRegressor(max_depth = 6, random_state = 42)

# Training the model on the training dataset
tree = tree.fit(X_train, y_train)

# predict based on the trained model 
y_pred = tree.predict(X_test)

# checking for the accuracy of the model 
print("The accuracy on the training dataset is: %f " %tree.score(X_train, y_train))
print("The accuracy on the testing dataset is: %f " %tree.score(X_test, y_test))
# Out:
# The accuracy on the training dataset is: 0.924578
# The accuracy on the testing dataset is: 0.674575

# %%
# comparing actual and predicted values
comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(comparison_df.head())

sns.lineplot(data=comparison_df)
plt.title("Model Predictions")
# Out:
#        Actual  Predicted
# 65   0.269753   1.249513
# 313 -2.254703  -1.086997
# 150 -1.542313  -0.543855
# 158  2.112020   1.961903
# 108 -0.619403  -0.286302
# Text(0.5, 1.0, 'Model Predictions')

# %% [markdown]
# #### we can see here that the model prediction accuracy is  on point

# %%
# creating a list with the test features
test_features = ['GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']

# %%
# Get numerical feature importances
importances = list(tree.feature_importances_)

# We now connect each feature with its importance
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(test_features, importances)]

# Sorting feature importances in descending order
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
feature_importances

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Healthy life expectancy Importance: 0.64
# Variable: Perceptions of corruption Importance: 0.11
# Variable: GDP per capita       Importance: 0.07
# Variable: Generosity           Importance: 0.07
# Variable: Freedom to make life choices Importance: 0.06
# Variable: Social support       Importance: 0.05

# %%
# Listing x locations for plotting
x_values = list(range(len(importances)))
plt.figure(figsize = (12, 8))
# Plotting a bar chart
sns.barplot(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, test_features, rotation = 45
           )
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %% [markdown]
# ## Conclusion
#
# ##### From our observation we are able to see that the healthy life expectancy is the most important feature followed by perceptions of corruption and GPD per capita.
#
# ## We then say that for the people to remain happy each national must be able to to ensure that people's lives comes first. if people are healthy and are able to trust the government in dealing with corruption then they remain happier.
#
# ## The GDP has some effect on people's happiness.
#
# #### it is evident from the analysis that as much as all other factors must remain balanced, people's health comes first and as such  they should focus there.

# %% [markdown]
# ------------------------------------------------
#
# ##### THIS REPORT WAS WRITTEN BY: LIVHALANI DAU
